# %% [markdown]
# ## Week 2

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Use and experience methods from previous lessons with given data. Try to search for other pandas methods to analyze the data such as groupby() and read_csv().

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Odevler/data/sales_data.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.drop_duplicates(inplace= True)

# %%
df.sort_values(by = "Revenue")
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 100529  2016-01-12   12   January  2016            30  Young Adults (25-34)
# 98282   2016-03-12   12     March  2016            45        Adults (35-64)
# 84668   2013-12-26   26  December  2013            23           Youth (<25)
# 88092   2016-01-10   10   January  2016            54        Adults (35-64)
# 84646   2015-10-29   29   October  2015            23           Youth (<25)
# ...            ...  ...       ...   ...           ...                   ...
# 70699   2011-07-17   17      July  2011            30  Young Adults (25-34)
# 59919   2011-03-20   20     March  2011            29  Young Adults (25-34)
# 71129   2011-07-08    8      July  2011            22           Youth (<25)
# 112072  2013-07-24   24      July  2013            52        Adults (35-64)
# 112073  2015-07-24   24      July  2015            52        Adults (35-64)
#
# ...

# %%
df.fillna(0, inplace= True)

# %%
groups = df.groupby("Country")

# %%
groups.first()
# Out:
#                       Date  Day      Month  Year  Customer_Age  \
# Country
# Australia       2014-03-23   23      March  2014            49
# Canada          2013-11-26   26   November  2013            19
# France          2013-07-15   15       July  2013            52
# Germany         2013-08-07    7     August  2013            38
# United Kingdom  2013-09-17   17  September  2013            29
# United States   2014-03-27   27      March  2014            51
#
#                            Age_Group Customer_Gender              State  \
# Country
# Australia             Adults (35-64)               M    New South Wales
# Canada                   Youth (<25)               M   British Columbia
# France                Adults (35-64)               F  Seine Saint Denis
# Germany               Adults (35-64)               M           Saarland
# United Kingdom  Young Adults (25-34)               F            England
# ...

# %%
# Finding the values contained "Australia" in the group
groups.get_group("Australia")
# Out:
#               Date  Day    Month  Year  Customer_Age             Age_Group  \
# 2       2014-03-23   23    March  2014            49        Adults (35-64)
# 3       2016-03-23   23    March  2016            49        Adults (35-64)
# 4       2014-05-15   15      May  2014            47        Adults (35-64)
# 5       2016-05-15   15      May  2016            47        Adults (35-64)
# 6       2014-05-22   22      May  2014            47        Adults (35-64)
# ...            ...  ...      ...   ...           ...                   ...
# 112999  2016-04-06    6    April  2016            58        Adults (35-64)
# 113008  2014-01-18   18  January  2014            32  Young Adults (25-34)
# 113009  2016-01-18   18  January  2016            32  Young Adults (25-34)
# 113032  2014-04-02    2    April  2014            18           Youth (<25)
# 113033  2016-04-02    2    April  2016            18           Youth (<25)
#
# ...

# %%
groups["Revenue"].describe()
# Out:
#                   count        mean          std  min   25%    50%    75%  \
# Country
# Australia       23736.0  893.006193  1485.841657  2.0  70.0  304.0  974.0
# Canada          14027.0  563.640265  1112.655734  2.0  54.0  149.0  594.0
# France          10920.0  770.581044  1286.885219  2.0  61.0  256.0  855.0
# Germany         11027.0  812.253922  1294.676481  2.0  78.0  316.0  893.0
# United Kingdom  13486.0  784.193089  1264.443729  2.0  77.0  259.0  881.0
# United States   38840.0  715.167302  1282.702578  2.0  59.0  197.0  754.0
#
#                     max
# Country
# Australia       58074.0
# Canada          14312.0
# France          13740.0
# Germany         14169.0
# United Kingdom  13740.0
# United States   14026.0

# %%
groups["Cost"].describe()
# Out:
#                   count        mean          std  min   25%    50%    75%  \
# Country
# Australia       23736.0  609.027342  1074.956997  1.0  32.0  156.0  713.0
# Canada          14027.0  299.719327   676.302071  1.0  24.0   60.0  247.0
# France          10920.0  507.569872   905.378437  1.0  28.0  130.0  496.5
# Germany         11027.0  508.454974   865.703088  1.0  32.0  153.0  504.0
# United Kingdom  13486.0  459.116195   794.976692  1.0  29.0  126.0  461.0
# United States   38840.0  432.014933   843.098455  1.0  27.0   91.0  377.0
#
#                     max
# Country
# Australia       42978.0
# Canada           8684.0
# France           8684.0
# Germany          8684.0
# United Kingdom   8684.0
# United States    8684.0

# %%
groups.value_counts()
# Out:
# Country        Date        Day  Month    Year  Customer_Age  Age_Group             Customer_Gender  State       Product_Category  Sub_Category       Product                     Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  Revenue
# Australia      2011-01-01  1    January  2011  23            Youth (<25)           M                Victoria    Bikes             Mountain Bikes     Mountain-200 Black, 46      1               1252       2295        561     1252  1813       1
#                2011-01-02  2    January  2011  40            Adults (35-64)        M                Victoria    Bikes             Road Bikes         Road-550-W Yellow, 40       4               713        1120        687     2852  3539       1
#                2016-01-26  26   January  2016  26            Young Adults (25-34)  M                Queensland  Accessories       Bottles and Cages  Road Bottle Cage            27              3          9           123     81    204        1
# ...

# %%
groups["Product_Category"].value_counts()
# Out:
# Country         Product_Category
# Australia       Accessories         13341
#                 Bikes                7023
#                 Clothing             3372
# Canada          Accessories         10088
#                 Clothing             2398
#                 Bikes                1541
# France          Accessories          6615
#                 Bikes                2765
#                 Clothing             1540
# Germany         Accessories          6481
#                 Bikes                3042
#                 Clothing             1504
# United Kingdom  Accessories          8019
#                 Bikes                3485
#                 Clothing             1982
# United States   Accessories         24768
#                 Bikes                7938
#                 Clothing             6134
# Name: Product_Category, dtype: int64
